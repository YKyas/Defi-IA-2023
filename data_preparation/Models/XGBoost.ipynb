# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import random
import os
from math import *

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error as MAE

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d79433b2-aa7c-4ad4-951c-2dc5446dd80f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d79433b2-aa7c-4ad4-951c-2dc5446dd80f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df_original = pd.read_csv(io.BytesIO(uploaded['df_complete.csv']))

# %%
df_original = df_original.drop(df_original.columns[[0]], axis=1)

# %%
df_original
# Out:
#         hotel_id  price  stock        city  date language  mobile  avatar_id
# 0            151    241     70        rome    22  latvian       0      90844
# 1             38    100     15        rome    22  latvian       0      90844
# 2            129    106     22        rome    22  latvian       0      90844
# 3            344     72     19        rome    22  latvian       0      90844
# 4            180     75     10        rome    22  latvian       0      90844
# ...          ...    ...    ...         ...   ...      ...     ...        ...
# 275500       994    197      1  copenhagen     1    czech       0      90843
# 275501        58    328      1  copenhagen     1    czech       0      90843
# 275502       445     91      0  copenhagen     1    czech       0      90843
# 275503        53     96      0  copenhagen     1    czech       0      90843
# 275504       664    482      1  copenhagen     1    czech       0      90843
#
# [275505 rows x 8 columns]

# %%
y = df_original['price']
X = df_original.copy()
del X['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
from xgboost import XGBRegressor
regressor = XGBRegressor(learning_rate=0.01,  
                      colsample_bytree = 1,
                      subsample = 1,
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=10, 
                      gamma=0)
regressor.fit(X_train,y_train)
# Out:
# [10:56:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=0.3)

# %%
Y_pred_test = regressor.predict(X_test)

# %%
MAPE(y_test, Y_pred_test)
# Out:
# 0.11601618148327117

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f1bc37f9-f46a-4676-a5c4-fd8226cc553f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1bc37f9-f46a-4676-a5c4-fd8226cc553f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_test = pd.read_csv(io.BytesIO(uploaded['test_set.csv']))

# %%
df_test
# Out:
#       index  order_requests     city  date  language  mobile  avatar_id  \
# 0         0               1  vilnius    21  romanian       0          1
# 1         1               1  vilnius    21  romanian       0          1
# 2         2               1  vilnius    21  romanian       0          1
# 3         3               1  vilnius    21  romanian       0          1
# 4         4               1  vilnius    21  romanian       0          1
# ...     ...             ...      ...   ...       ...     ...        ...
# 6639   6639             843     rome     5     irish       0        794
# 6640   6640             844   vienna     1     irish       1        794
# 6641   6641             844   vienna     1     irish       1        794
# 6642   6642             844   vienna     1     irish       1        794
# 6643   6643             844   vienna     1     irish       1        794
#
#       hotel_id  stock
# 0          161     46
# 1          187     32
# 2          279     12
# ...

# %%
#change the order of columns to match training
df_test = df_test.iloc[:,[0,1,7,8,3,5,6,2,4]]

# %%
df_test
# Out:
#       index  order_requests  hotel_id  stock  date  mobile  avatar_id  \
# 0         0               1       161     46    21       0          1
# 1         1               1       187     32    21       0          1
# 2         2               1       279     12    21       0          1
# 3         3               1       395     10    21       0          1
# 4         4               1       488     42    21       0          1
# ...     ...             ...       ...    ...   ...     ...        ...
# 6639   6639             843       987      1     5       0        794
# 6640   6640             844        26      1     1       1        794
# 6641   6641             844       263      0     1       1        794
# 6642   6642             844       456      0     1       1        794
# 6643   6643             844       699      0     1       1        794
#
#          city  language
# 0     vilnius  romanian
# 1     vilnius  romanian
# 2     vilnius  romanian
# 3     vilnius  romanian
# ...

# %%
df_test = pd.get_dummies(df_test)

# %%
del df_test['order_requests']
del df_test['index']

# %%
Y_pred_test = regressor.predict(df_test)

# %%
Y_pred_test_4 = pd.DataFrame(Y_pred_test)

# %%
Y_pred_test_4.to_csv('Y_pred_test_4.csv')
