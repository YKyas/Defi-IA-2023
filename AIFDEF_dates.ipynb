# %%
import numpy as np
import urllib.parse
import random
import requests


domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

user_id = '07c8d172-5838-4ff7-a8c3-a107546de381'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.cluster as sclust
from scipy import cluster
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
import numpy as np
import random
import seaborn as sns
from sklearn.preprocessing import scale
# %matplotlib inline

# %%
avatars = []
dates = np.arange(45)
cities = ['amsterdam', 'copenhagen', 'madrid', 'paris', 'rome', 'sofia', 'valletta', 'vienna', 'vilnius']
languages = ['austrian', 'belgian', 'bulgarian', 'croatian', 'cypriot', 'czech', 'danish', 'dutch',
             'estonian', 'finnish', 'french', 'german', 'greek', 'hungarian', 'irish', 'italian',
             'latvian', 'lithuanian', 'luxembourgish', 'maltese', 'polish', 'portuguese', 'romanian',
             'slovakian', 'slovene', 'spanish', 'swedish']
mobile = [0,1]

# %%
# import pandas module 
import pandas as pd 
    
# making dataframe 
df = pd.read_csv("test_set.csv") 
   
# output the dataframe
print(df)
# Out:
#       index  order_requests     city  date  language  mobile  avatar_id  \
# 0         0               1  vilnius    21  romanian       0          1
# 1         1               1  vilnius    21  romanian       0          1
# 2         2               1  vilnius    21  romanian       0          1
# 3         3               1  vilnius    21  romanian       0          1
# 4         4               1  vilnius    21  romanian       0          1
# ...     ...             ...      ...   ...       ...     ...        ...
# 6639   6639             843     rome     5     irish       0        794
# 6640   6640             844   vienna     1     irish       1        794
# 6641   6641             844   vienna     1     irish       1        794
# 6642   6642             844   vienna     1     irish       1        794
# 6643   6643             844   vienna     1     irish       1        794
#
#       hotel_id  stock
# 0          161     46
# 1          187     32
# 2          279     12
# ...

# %%
df['date']
# Out:
# 0       21
# 1       21
# 2       21
# 3       21
# 4       21
#         ..
# 6639     5
# 6640     1
# 6641     1
# 6642     1
# 6643     1
# Name: date, Length: 6644, dtype: int64

# %%
d_date=df['date'].value_counts()
d_date = d_date.to_frame(name='date')
d_date['percent'] = (d_date['date']/
                    d_date['date'].sum())*100
d_date
# Out:
#     date   percent
# 2    484  7.284768
# 1    467  7.028898
# 0    464  6.983745
# 5    458  6.893438
# 6    450  6.773028
# 3    449  6.757977
# 4    443  6.667670
# 16   281  4.229380
# 18   279  4.199278
# 21   268  4.033715
# 15   267  4.018663
# 35   264  3.973510
# 17   264  3.973510
# 20   252  3.792896
# 38   250  3.762793
# 37   241  3.627333
# 36   237  3.567128
# 19   235  3.537026
# 34   222  3.341361
# 39   189  2.844672
# 40   180  2.709211

# %%
d_percentage_d=d_date['percent'].round()
d_percentage_d=d_percentage_d.to_frame(name='percentage')
d_percentage_d=d_percentage_d['percentage'].astype('int')
d_percentage_d= d_percentage_d.to_dict()
d_percentage_d
# Out:
# {2: 7,
#  1: 7,
#  0: 7,
#  5: 7,
#  6: 7,
#  3: 7,
#  4: 7,
#  16: 4,
#  18: 4,
#  21: 4,
#  15: 4,
#  35: 4,
#  17: 4,
#  20: 4,
#  38: 4,
#  37: 4,
#  36: 4,
#  19: 4,
#  34: 3,
#  39: 3,
#  40: 3}

# %%
d_date
# Out:
#     date   percent
# 2    484  7.284768
# 1    467  7.028898
# 0    464  6.983745
# 5    458  6.893438
# 6    450  6.773028
# 3    449  6.757977
# 4    443  6.667670
# 16   281  4.229380
# 18   279  4.199278
# 21   268  4.033715
# 15   267  4.018663
# 35   264  3.973510
# 17   264  3.973510
# 20   252  3.792896
# 38   250  3.762793
# 37   241  3.627333
# 36   237  3.567128
# 19   235  3.537026
# 34   222  3.341361
# 39   189  2.844672
# 40   180  2.709211

# %%
l = np.array(d_percentage_d.values())
print(l.sum())
# Out:
# dict_values([7, 7, 7, 7, 7, 7, 7, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 3])

# %%
df['language'].value_counts()
# Out:
# hungarian        967
# finnish          466
# austrian         461
# romanian         439
# slovakian        418
# swedish          404
# estonian         390
# bulgarian        356
# danish           346
# irish            209
# maltese          197
# greek            181
# slovene          174
# belgian          153
# spanish          141
# dutch            134
# polish           131
# italian          128
# french           128
# luxembourgish    125
# lithuanian       122
# latvian          113
# cypriot          106
# czech            104
# croatian         101
# german            80
# portuguese        70
# Name: language, dtype: int64

# %%
summary=df.describe()
summary
# Out:
#              index  order_requests         date       mobile    avatar_id  \
# count  6644.000000     6644.000000  6644.000000  6644.000000  6644.000000
# mean   3321.500000      419.312763    15.201084     0.453642   381.219597
# std    1918.101926      246.445963    13.783346     0.497884   243.526271
# min       0.000000        1.000000     0.000000     0.000000     1.000000
# 25%    1660.750000      202.000000     3.000000     0.000000   171.000000
# 50%    3321.500000      415.500000    15.000000     0.000000   381.000000
# 75%    4982.250000      636.000000    21.000000     1.000000   589.250000
# max    6643.000000      844.000000    40.000000     1.000000   794.000000
#
#           hotel_id        stock
# count  6644.000000  6644.000000
# mean    472.193709    23.766105
# std     280.681105    32.582240
# min       0.000000     0.000000
# 25%     252.000000     2.000000
# 50%     449.000000     8.000000
# 75%     702.000000    33.000000
# max     995.000000   199.000000

# %%
df2=df.groupby(['city','language']).mean()
df2
# Out:
#                            index  order_requests       date    mobile  \
# city      language
# amsterdam austrian   1745.579832      217.159664  15.789916  0.529412
#           belgian     499.000000       60.000000  17.000000  0.000000
#           bulgarian  3886.333333      492.142857  24.047619  0.000000
#           croatian   5850.500000      745.000000   4.000000  0.000000
#           czech      3309.083333      415.250000  16.500000  0.583333
# ...                          ...             ...        ...       ...
# vilnius   romanian   1090.734694      137.448980  22.081633  0.571429
#           slovakian  3055.423077      384.230769  28.269231  0.000000
#           slovene    4187.000000      528.000000   2.000000  0.000000
#           spanish    2412.818182      300.818182  24.500000  0.545455
#           swedish    3699.000000      469.045455  25.022727  0.500000
#
#                       avatar_id    hotel_id      stock
# city      language
# ...

# %%
d_percentage_d.keys()
# Out:
# dict_keys([2, 1, 0, 5, 6, 3, 4, 16, 18, 21, 15, 35, 17, 20, 38, 37, 36, 19, 34, 39, 40])

# %%
d_percentage_d.values()
# Out:
# dict_values([7, 7, 7, 7, 7, 7, 7, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 3])

# %%
c=203
list_requests=[]
for dat in d_percentage_d.keys():
    for i in range(d_percentage_d[dat]):
        name = 'yaa-'+str(c)+'-avatar'
        r = requests.post(path(f'avatars/{user_id}/{name}'))
        params = {
            "avatar_name": name,
            "language": random.choice(languages) ,
            "city": random.choice(cities),
            "date": dat,
            "mobile": random.choice(mobile)
            }
        list_requests.append(requests.get(path(f"pricing/{user_id}"), params=params))
        c+=1

# %%
test_list=[]
name = 'yaa-0000-avatar'
r = requests.post(path(f'avatars/{user_id}/{name}'))
params = {
    "avatar_name": name,
    "language": random.choice(languages) ,
    "city": random.choice(cities),
    "date": 2,
    "mobile": random.choice(mobile)
                }
test_list.append(requests.get(path(f"pricing/{user_id}"), params=params))

# %%
test_pricing_requests = []

for r in test_list:
    test_pricing_requests.append(
        pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])
    )

test_pricing_requests = pd.concat(test_pricing_requests)
test_pricing_requests
# Out:
#     hotel_id  price  stock   city  date language  mobile  avatar_id
# 0        137     47      0  sofia     2   german       1      59853
# 1        542     66      0  sofia     2   german       1      59853
# 2        262    103      0  sofia     2   german       1      59853
# 3        554     47      0  sofia     2   german       1      59853
# 4        597    254      2  sofia     2   german       1      59853
# 5        683     91      0  sofia     2   german       1      59853
# 6        383     46      0  sofia     2   german       1      59853
# 7        665     65      8  sofia     2   german       1      59853
# 8        923     56      0  sofia     2   german       1      59853
# 9        899     95      2  sofia     2   german       1      59853
# 10       302     63      0  sofia     2   german       1      59853
# 11       181    106      0  sofia     2   german       1      59853
# 12       764     67      0  sofia     2   german       1      59853
# ...

# %%
list_requests
# Out:
# [<Response [422]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
list_requests_date203=list_requests

# %%
pd.DataFrame(list_requests[0].json()['prices']).assign(**list_requests[0].json()['request'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-c582a8d9f5ed> in <module>
# ----> 1 pd.DataFrame(list_requests[0].json()['prices']).assign(**list_requests[0].json()['request'])
#
# KeyError: 'prices'

# %%
date_pricing_requests = []

for r in list_requests:
    date_pricing_requests.append(
        pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])
    )

date_pricing_requests = pd.concat(date_pricing_requests)
date_pricing_requests
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-5b7c73939481> in <module>
#       3 for r in list_requests:
#       4     date_pricing_requests.append(
# ----> 5         pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])
#       6     )
#       7
#
# KeyError: 'prices'

# %%
test_pricing_requests.to_csv('pricing_requests_dates_avatar0000.csv')

# %%
pricing_requests['avatar_id'].unique()

# %%
pricing_requests.to_csv("pricing_requests_for_amsterdam.csv")
